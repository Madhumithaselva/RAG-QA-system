# %%
# Install compatible versions together
# !pip install langchain-google-genai langchain langchain-community -q
# !pip install chromadb -q
# !pip install sentence-transformers -q
# !pip install pypdf -q
# !pip install streamlit -q
# !pip install pyngrok -q

print("All libraries installed!")
# Out:
# All libraries installed!

# %%
import os

# Paste your Groq API key here
GROQ_API_KEY = "REDACTED "

os.environ["GROQ_API_KEY"] = GROQ_API_KEY

if GROQ_API_KEY == "gsk_paste-your-key-here":
    print("Please paste your real Groq API key!")
else:
    print(f"Groq API key set! (starts with: {GROQ_API_KEY[:8]}...)")
# Out:
# Groq API key set! (starts with: gsk_mpbr...)
